# %% [markdown]
# # Kata 2 - Ejercicio - Crear un paquete

# %% [markdown]
# Crear un entorno virtual

# %%
from IPython.display import Image
Image("img/crearenv.png")

# %% [markdown]
# Activar el entorno virtual

# %%
from IPython.display import Image
Image("img/activarenv.png")

# %% [markdown]
# Instalar una biblioteca

# %%
from IPython.display import Image
Image("img/instalarbiblioteca.png")

# %% [markdown]
# Usar un paquete instalado

# %%
from IPython.display import Image
Image("img/paqueteinstalado.png")

# %% [markdown]
# Desactivar un entorno virtual

# %%
from IPython.display import Image
Image("img/desactivarenv.png")
